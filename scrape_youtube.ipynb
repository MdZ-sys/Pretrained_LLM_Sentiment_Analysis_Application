# %%
#%pip install htmldate selenium pandas mysql-connector-python google-api-python-client googlesearch-python

# %%
# import random
# import time
# from htmldate import find_date
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.common.by import By
# import pandas as pd

# import mysql.connector

# from googleapiclient.discovery import build
# from googleapiclient.errors import HttpError
# from datetime import datetime
# import time
# import urllib
# from googlesearch import search

# %%
import random
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from datetime import datetime
import pandas as pd

# %%
API_KEY = 'AIzaSyCDZks-ZYM2beAgY0JibxaxECjMLxdB1No'

# %%
def get_video_details(youtube, video_id):
    response = youtube.videos().list(
        part='snippet',
        id=video_id
    ).execute()

    video_details = response['items'][0]['snippet']
    channel_name = video_details['channelTitle']
    published_date = datetime.strptime(video_details['publishedAt'], '%Y-%m-%dT%H:%M:%S%z').date()
    return channel_name, published_date

def get_video_comments(youtube, video_ids):
    comments_data = []

    video_request = youtube.commentThreads().list(
        part='snippet',
        videoId=','.join(video_ids),
        maxResults=50  # You can increase this
    )
    video_response = video_request.execute()

    video_details = {}

    for item in video_response['items']:
        video_id = item['snippet']['videoId']
        comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
        username = item['snippet']['topLevelComment']['snippet']['authorDisplayName']
        published_date = datetime.strptime(item['snippet']['topLevelComment']['snippet']['publishedAt'], '%Y-%m-%dT%H:%M:%S%z').date()

        channel_name, _ = video_details.get(video_id, ("", None))

        comments_data.append({
            'Date': published_date,
            'Media Source': 'YouTube Comments',
            'Domain Name': channel_name,
            'URL': f'https://www.youtube.com/watch?v={video_id}',
            'Likes': 0,
            'Comments': 0,
            'Shares': 0,
            'Is Reply': False,
            'Commenter Name': username,
            'Comment Text': comment
        })

    return comments_data

def scrap_youtube_comments(query, num_of_videos):
    youtube = build('youtube', 'v3', developerKey=API_KEY)

    video_data = search_videos(youtube, query, num_of_videos)
    video_ids = [video['videoId'] for video in video_data]

    # Fetch video details for all video_ids
    video_details = {video_id: get_video_details(youtube, video_id) for video_id in video_ids}

    comments_data = get_video_comments(youtube, video_ids)
    return comments_data

def search_videos(youtube, query, num_of_videos):
    request = youtube.search().list(
        part='snippet',
        q=query,
        type='video',
        maxResults=num_of_videos
    )
    response = request.execute()
    return [{'url': f'https://www.youtube.com/watch?v={item["id"]["videoId"]}', 'videoId': item['id']['videoId']} for item in response['items']]

# %%
query = "Simple One Scooter Reviews"
comments_data = scrap_youtube_comments(query, 1)

# Convert the list of dictionaries into a pandas DataFrame
df = pd.DataFrame(comments_data)

# Display the DataFrame
df
# Out:
#           Date  ...                                       Comment Text
# 0   2023-05-13  ...                     why this looks like ather 450x
# 1   2023-05-12  ...                          No competition with ola 😅
# 2   2023-04-25  ...  If everything goes well this will be a big hit...
# 3   2023-03-31  ...          One of the oldest auto channel in YouTube
# 4   2023-02-23  ...  1and hlf yr bck I was thinking to tk franchise...
# 5   2023-02-21  ...                                   Modified Ather 😄
# 6   2023-02-19  ...  I am waiting for a long time for this scooty p...
# 7   2023-02-18  ...                  Romovable battery is an advantage
# 8   2023-02-16  ...                  Bro make a video hill climb test.
# 9   2023-02-14  ...                                   Looks like ather
# 10  2023-02-06  ...  Bahi a scooter lonch hoonekaaa naame heeee nah...
# 11  2023-02-04  ...          Sir tell about up coming electric scooter
# ...
